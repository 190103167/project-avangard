# %%
try:
    my=my = cx_Oracle.connect('hr/hr@//localhost:1521/orcl')
except Exception as err:
    print('Error',err)
else:
    try:
        cur=my.cursor()
        del_product()
    except Exception as err:
        print('Error',err)
    else:
        print('Procedure Executed')
    finally:
        cur.close()
finally:
    my.close()

def del_product():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_product',(x1,x2))
def del_description():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_description',(x1,x2))
def del_category():
    x1=int(input('Введите Category ID для удаление:'))
    x2=3
    cur.callproc('del_category',(x1,x2))
def del_cart():
    x1=int(input('Введите Cart ID для удаление:'))
    x2=3
    cur.callproc('del_cart',(x1,x2))
def del_customer():
    x1=int(input('Введите Customer ID для удаление:'))
    x2=3
    cur.callproc('del_customer',(x1,x2))
def del_address():
    x1=int(input('Введите Address ID для удаление:'))
    x2=3
    cur.callproc('del_address',(x1,x2))
def del_store():
    x1=int(input('Введите Store ID для удаление:'))
    x2=3
    cur.callproc('del_store',(x1,x2))
def del_prodstore():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_prodstore',(x1,x2))
def del_prodcategory():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_prodcategory',(x1,x2))
# Out:
# Введите Product ID для удаление: f
# Error invalid literal for int() with base 10: 'f'

# %%
import cx_Oracle
try:
    my= cx_Oracle.connect('hr/hr@//localhost:1521/orcl')
except Exception as err:
    print('Error',err)
else:
    try:
        cur=my.cursor()
        print('ЗДРАВСТВУЙТЕ, ЧТО ХОТЕЛИ БЫ СДЕЛАТЬ?')
        def project():
            print('1.Вывести данные с таблицы')
            print('2.Добавить данные в таблицу')
            print('3.Обновить данные в таблице')
            print('4.Удалить данные с таблицы')
            print('5.Выйти')
            z1=int(input('Введите цифру:'))
            if z1==1:
                print('\nКАКУЮ ТАБЛИЦУ ХОТИТЕ ВЫВЕСТИ ?')
                print('1.Products')
                print('2.Product_description')
                print('3.Product_category')
                print('4.Category')
                print('5.Cart')
                print('6.Customer')
                print('7.Address')
                print('8.Store')
                print('9.Product_store')
                z2=int(input('Введите цифру:'))
                print(' ')
                if z2==1:
                    get_product()
                elif z2==2:
                    get_description()
                elif z2==3:
                    get_prodcategory()
                elif z2==4:
                    get_category()
                elif z2==5:
                    get_cart()
                elif z2==6:
                    get_customer()
                elif z2==7:
                    get_address()
                elif z2==8:
                    get_store()
                elif z2==9:
                    get_prodstore()
                print(' ')
                try:
                    a1=input('Хотите снова совершить процедуру?')
                    a1=a1.upper()
                    if a1=='YES':
                        project()
                    elif a1=='NO':
                        print('\n Thank you for coming, come again.')
                except Exception as err:
                    print('Error',err)
            elif z1==2:
                print('\nВ КАКУЮ ТАБЛИЦУ ХОТИТЕ ДОБАВИТЬ ДАННЫЕ?')
                print('1.Products')
                print('2.Product_description')
                print('3.Product_category')
                print('4.Category')
                print('5.Cart')
                print('6.Customer')
                print('7.Address')
                print('8.Store')
                print('9.Product_store')
                z2=int(input('Введите цифру:'))
                print(' ')
                if z2==1:
                    add_product()
                    get_product()
                elif z2==2:
                    add_description()
                    get_description()
                elif z2==3:
                    add_prodcategory()
                    get_prodcategory()
                elif z2==4:
                    add_category()
                    get_category()
                elif z2==5:
                    add_cart()
                    get_cart()
                elif z2==6:
                    add_customer()
                    get_customer()
                elif z2==7:
                    add_address()
                    get_address()
                elif z2==8:
                    add_store()
                    get_store()
                elif z2==9:
                    add_prodstore()
                    get_prodstore()
                print(' ')
                a1=input('Хотите снова совершить процедуру?')
                a1=a1.upper()
                if a1=='YES':
                    project()
                elif a1=='NO':
                    print('\n Thank you for coming, come again.')
            elif z1==3:
                print('\n КАКУЮ ТАБЛИЦУ ХОТИТЕ ОБНОВИТЬ?')
                print('1.Products')
                print('2.Product_description')
                print('3.Category')
                print('4.Cart')
                print('5.Customer')
                print('6.Address')
                print('7.Store')
                z2=int(input('Введите цифру:'))
                print(' ')
                if z2==1:
                    upd_product()
                    get_product()
                elif z2==2:
                    upd_description()
                    get_description()
                elif z2==3:
                    upd_category()
                    get_category()
                elif z2==4:
                    upd_cart()
                    get_cart()
                elif z2==5:
                    upd_customer()
                    get_customer()
                elif z2==6:
                    upd_address()
                    get_address()
                elif z2==7:
                    upd_store()
                    get_store()
                print(' ')
                a1=input('Хотите снова совершить процедуру?')
                a1=a1.upper()
                if a1=='YES':
                    project()
                elif a1=='NO':
                    print('\n Thank you for coming, come again.')
            elif z1==4:
                print('\n В КАКОЙ ТАБЛИЦЕ ХОТИТЕ УДАЛИТЬ ДАННЫЕ?')
                print('1.Products')
                print('2.Product_description')
                print('3.Product_category')
                print('4.Category')
                print('5.Cart')
                print('6.Customer')
                print('7.Address')
                print('8.Store')
                print('9.Product_store')
                z2=int(input('Введите цифру:'))
                print(' ')
                if z2==1:
                    del_product()
                    get_product()
                elif z2==2:
                    del_description()
                    get_description()
                elif z2==3:
                    del_prodcategory()
                    get_prodcategory()
                elif z2==4:
                    del_category()
                    get_category()
                elif z2==5:
                    del_cart()
                    get_cart()
                elif z2==6:
                    del_customer()
                    get_customer()
                elif z2==7:
                    del_address()
                    get_address()
                elif z2==8:
                    del_store()
                    get_store()
                elif z2==9:
                    del_prodstore()
                    get_prodstore()
                print(' ')
                a1=input('Хотите снова совершить процедуру?')
                a1=a1.upper()
                if a1=='YES':
                    project()
                elif a1=='NO':
                    print('\n Thank you for coming, come again.')
            elif z1==5:
                print('\n Thank you for coming, come again.')
        project()
    except Exception as err:
        print('Error',err)
        print(' ')
        project()
    else:
        print('Procedure Executed')
    finally:
        cur.close()
finally:
    my.close()
    
    
    
    
    
def get_product():
    cur=my.cursor()
    cur.execute("select * from products")
    REC=cur.fetchall()
    for i in REC:
        print('Product_id:', i[0],'Product_name: '+i[1],'Price:',i[2])

def get_description():
    cur=my.cursor()
    cur.execute("select * from product_description")
    REC=cur.fetchall()
    for i in REC:
        print('Product_id:', i[0],'Description:',i[1])
        
def get_address():
    cur=my.cursor()
    cur.execute("select * from address")
    REC=cur.fetchall()
    for i in REC:
        print('Address_id:', i[0],'Customer_id:',i[1],'Address:',i[2])
        
def get_category():
    cur=my.cursor()
    cur.execute("select * from category")
    REC=cur.fetchall()
    for i in REC:
        print('Category_id:',i[0],'Category_name:',i[1])
def get_prodcategory():
    cur=my.cursor()
    cur.execute("select * from product_category")
    REC=cur.fetchall()
    for i in REC:
        print('Product_id:', i[0],'Category_id:',i[1])
def get_cart():
    cur=my.cursor()
    cur.execute("select * from cart")
    REC=cur.fetchall()
    for i in REC:
        print('Product_id:', i[1],'Cart_id:',i[0],'Customer_id:',i[2])  

def get_customer():
    cur=my.cursor()
    cur.execute("select * from customer")
    REC=cur.fetchall()
    for i in REC:
        print('Customer_id:', i[0],'Store_id:',i[1],'Name:',i[2],i[3],' Email:',i[4],' Number:',i[5])  

def get_store():
    cur=my.cursor()
    cur.execute("select * from store")
    REC=cur.fetchall()
    for i in REC:
        print('Store_id:', i[0],'Store_name:',i[1],' Rating:',i[2])   

def get_prodstore():
    cur=my.cursor()
    cur.execute("select * from product_store")
    REC=cur.fetchall()
    for i in REC:
        print('Product_id:', i[0],'Store_id:',i[1])

def add_product():
    x1=int(input('Введите новый Product ID:'))
    x2=input('Введите новый Name Product:')
    x3=int(input('Введите новый Price:'))
    cur.callproc('add_product',(x1,x2,x3))
    
def add_category():
    x1=int(input('Введите новый ID:'))
    x2=input('Введите новый Category Name:')
    cur.callproc('add_category',(x1,x2))
    
def add_prodcategory():
    x1=int(input('Введите новый Product ID:'))
    x2=int(input('Введите новый Category ID:'))
    cur.callproc('add_prodcategory',(x1,x2))    

def add_customer():
    x1=int(input('Введите новый Customer ID:'))
    x2=int(input('Введите новый Store ID:'))
    x3=input('Введите новый First Name:')
    x4=input('Введите новый Last Name:')
    x5=input('Введите новый Email:')
    x6=int(input('Введите новый telephone:'))
    cur.callproc('add_customer',(x1,x2,x3,x4,x5,x6))

def add_cart():
    x1=int(input('Введите новый Cart ID:'))
    x2=int(input('Введите новый Product ID:'))
    x3=int(input('Введите новый Customer ID:'))
    cur.callproc('add_cart',(x1,x2,x3))

def add_description():
    x1=int(input('Введите новый Product ID:'))
    x2=input('Введите новый Description:')
    cur.callproc('add_description',(x1,x2))
    
def add_address():
    x1=int(input('Введите новый Address ID:'))
    x2=int(input('Введите новый Customer ID:'))
    x3=input('Введите новый Address:')
    cur.callproc('add_address',(x1,x2,x3))
    
def add_store():
    x1=int(input('Введите новый Store ID:'))
    x2=input('Введите новый Name Store:')
    x3=int(input('Введите новый Rating:'))
    cur.callproc('add_store',(x1,x2,x3))
    
def add_prodstore():
    x1=int(input('Введите новый Product ID:'))
    x2=int(input('Введите новый Store ID:'))
    cur.callproc('add_prodstore',(x1,x2))
    
def upd_product():
            x4=int(input('Введите сколько изменении:'))
            if x4==1:
                x5=input('Введите название столбца которое надо изменить:')
                if x5=='price':
                    x2='hi'
                    x1=int(input('Введите Product ID:'))
                    x3=int(input('Введите новый Price:'))
                    cur.callproc('upd_product',(x4,x5,x1,x2,x3))
                elif x5=='name':
                    x1=int(input('Введите Product ID:'))
                    x2=input('Введите новый Name Product:')
                    cur.callproc('upd_product',(x4,x5,x1,x2,x3))
            elif x4==2:
                x5='hi'
                x1=int(input('Введите Product ID:'))
                x2=input('Введите новый Name Product:')
                x3=int(input('Введите новый Price:'))
                cur.callproc('upd_product',(x4,x5,x1,x2,x3))
def upd_description():
    x1=int(input('Введите Product ID:'))
    x2=input('Введите новый Description:')
    cur.callproc('upd_description',(x1,x2))
    
def upd_category():
    x1=int(input('Введите Category ID:'))
    x2=input('Введите новый Category Name:')
    cur.callproc('upd_category',(x1,x2))
    
def upd_store():
    x4=int(input('Введите сколько изменении:'))
    if x4==1:
        x5=input('Введите название столбца которое надо изменить:')
        if x5=='rating':
            x2='hi'
            x1=int(input('Введите Store ID:'))
            x3=int(input('Введите новый Rating:'))
            cur.callproc('upd_store',(x4,x5,x1,x2,x3))
        elif x5=='name':
            x1=int(input('Введите Store ID:'))
            x2=input('Введите новый Name Store:')
            cur.callproc('upd_store',(x4,x5,x1,x2,x3))
    elif x4==2:
        x5='hi'
        x1=int(input('Введите Store ID:'))
        x2=input('Введите новый Name Store:')
        x3=int(input('Введите новый Rating:'))
        cur.callproc('upd_store',(x4,x5,x1,x2,x3))

def upd_address():
    x1=int(input('Введите Address ID:'))
    x2=input('Введите новый Address Name:')
    cur.callproc('upd_address',(x1,x2))
    
def upd_customer():
    x1=input('Введите что хотите изменить:')
    if x1=='store_id':
        x3='hi'
        x2=int(input('Введите Customer ID:'))
        x4=int(input('Введите новый Store ID:'))
        cur.callproc('upd_customer',(x1,x2,x3,x4))
    elif x1=='f_name':
        x2=int(input('Введите Customer ID:'))
        x3=input('Введите новый First Name:')
        x4=0
        cur.callproc('upd_customer',(x1,x2,x3,x4))
    elif x1=='l_name':
        x2=int(input('Введите Customer ID:'))
        x3=input('Введите новый Last Name:')
        cur.callproc('upd_customer',(x1,x2,x3,x4))
        x4=0
    elif x1=='email':
        x2=int(input('Введите Customer ID:'))
        x3=input('Введите новый Email:')
        x4=0
        cur.callproc('upd_customer',(x1,x2,x3,x4))
    elif x1=='telephone':
        x3='hi'
        x2=int(input('Введите Customer ID:'))
        x4=int(input('Введите новый Telephone:'))
        cur.callproc('upd_customer',(x1,x2,x3,x4))
            
def upd_cart():
    x1=int(input('Введите Cart ID:'))
    x2=int(input('Введите новый Product ID:'))
    cur.callproc('upd_cart',(x1,x2))

def del_product():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_product',(x1,x2))
def del_description():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_description',(x1,x2))
def del_category():
    x1=int(input('Введите Category ID для удаление:'))
    x2=3
    cur.callproc('del_category',(x1,x2))
def del_cart():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_cart',(x1,x2))
def del_customer():
    x1=int(input('Введите Customer ID для удаление:'))
    x2=3
    cur.callproc('del_customer',(x1,x2))
def del_address():
    x1=int(input('Введите Address ID для удаление:'))
    x2=3
    cur.callproc('del_address',(x1,x2))
def del_store():
    x1=int(input('Введите Store ID для удаление:'))
    x2=3
    cur.callproc('del_store',(x1,x2))
def del_prodstore():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_prodstore',(x1,x2))
def del_prodcategory():
    x1=int(input('Введите Product ID для удаление:'))
    x2=3
    cur.callproc('del_prodcategory',(x1,x2))
# Out:
# ЗДРАВСТВУЙТЕ, ЧТО ХОТЕЛИ БЫ СДЕЛАТЬ?
# 1.Вывести данные с таблицы
# 2.Добавить данные в таблицу
# 3.Обновить данные в таблице
# 4.Удалить данные с таблицы
# 5.Выйти
# Введите цифру: 2
# В КАКУЮ ТАБЛИЦУ ХОТИТЕ ДОБАВИТЬ ДАННЫЕ?
# 1.Products
# 2.Product_description
# 3.Product_category
# 4.Category
# 5.Cart
# 6.Customer
# 7.Address
# 8.Store
# 9.Product_store
# Введите цифру: 8
# Введите новый Store ID: 6
# Введите новый Name Store: Pop
# Введите новый Rating: 2
# Store_id: 5 Store_name: Oppo  Rating: 5
# Store_id: 6 Store_name: Pop  Rating: 2
# Store_id: 1 Store_name: Iphone  Rating: 10
# Store_id: 2 Store_name: Samsung company  Rating: 9
# Store_id: 3 Store_name: I_style  Rating: 6
# Store_id: 4 Store_name: Brak  Rating: 3
# Хотите снова совершить процедуру? yes
# 1.Вывести данные с таблицы
# 2.Добавить данные в таблицу
# 3.Обновить данные в таблице
# 4.Удалить данные с таблицы
# 5.Выйти
# Введите цифру: 4
#  В КАКОЙ ТАБЛИЦЕ ХОТИТЕ УДАЛИТЬ ДАННЫЕ?
# 1.Products
# 2.Product_description
# ...
